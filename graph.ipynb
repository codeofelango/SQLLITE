# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df = pd.DataFrame(np.random.randn(1000),column=['data'],index = pd.date_range("2022/03/26",periods =1000))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8004/366329677.py in <module>
# ----> 1 df = pd.DataFrame(np.random.randn(1000),column=['data'],index = pd.date_range("2022/03/26",periods =1000))
#
# TypeError: __init__() got an unexpected keyword argument 'column'

# %%
df.plot(figsize=(20,10))

# %%
df = pd.read_csv("https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.plot(figsize =(20,10))

# %%
df = df.drop('Id', axis = 1)

# %%
df.plot(figsize =(20,8))

# %%
df.plot(kind = 'bar', figsize=(20,10))

# %%
df.head().plot(kind = 'bar', figsize=(20,10))

# %%
df.iloc[5:11].plot(kind = 'bar', figsize=(20,10))

# %%
df.iloc[5:11]

# %%
df.iloc[[5]].plot(kind = 'barh', figsize=(20,10))

# %%
df.plot(kind = 'hist').

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df['SepalLengthCm'].plot(kind='hist', orientation = 'horizontal')

# %%
df['SepalLengthCm']

# %%
df

# %%
df.hist(figsize=(20,10),color='r', alpha =.12)

# %% [raw]
# df

# %% [raw]
# df.plot(kind = 'box', figsize=(20,10),color ='g',vert = false)

# %%
df.describe()

# %%
df.plot(kind= "area", figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='SepalLengthCm',y="PetalLengthCm")
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x='SepalLengthCm',y="PetalLengthCm", gridsize=10, c="SepalWidthCm" )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8004/124221653.py in <module>
# ----> 1 df.plot.hexbin(x='SepalLengthCm',y="PetalLengthCm", gridsize=10, c="SepalWidthCm" )
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hexbin(self, x, y, C, reduce_C_function, gridsize, **kwargs)
#    1723             kwargs["gridsize"] = gridsize
#    1724
# -> 1725         return self(kind="hexbin", x=x, y=y, C=C, **kwargs)
#    1726
#    1727
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
#     916             if isinstance(data, ABCDataFrame):
# --> 917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
# ...

# %%
df.plot.scatter(x='SepalLengthCm',y="PetalLengthCm", c="SepalWidthCm", s=df['PetalWidthCm']*500)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.iloc[[0]].plot(kind="pie")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8004/1708849975.py in <module>
# ----> 1 df.iloc[[0]].plot(kind="pie")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     921             if isinstance(data, ABCDataFrame):
#     922                 if y is None and kwargs.get("subplots") is False:
# --> 923                     raise ValueError(
#     924                         f"{kind} requires either y column or 'subplots=True'"
#     925                     )
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
df1 = df.drop(columns="Species").iloc[0]

# %%
df1.plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='0'>

# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68734 sha256=e5f4a357bef79c5f6fea51681dd1abb451d5676a84212d188638a9718eeb0299
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...

# %%
import cufflinks as cf

# %%
pip install chart_studio
# Out:
# ...
#   Created wheel for retrying: filename=retrying-1.3.3-py3-none-any.whl size=11448 sha256=61df29ee5197390ec0eb426653da3c6c9b3bc07eee515ae017bb94e78826e795
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\ce\18\7f\e9527e3e66db1456194ac7f61eb3211068c409edceecff2d31
# Successfully built retrying
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df.plot(kind= "area", figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iplot(x='SepalLengthCm', y ='PetalLengthCm')
# Out:
# <div>                            <div id="a7d65b61-f7fe-4fb5-85d6-6e5d1c86688e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot(kind= "bubble",x='SepalLengthCm', y ='PetalLengthCm', size="SepalWidthCm")
# Out:
# <div>                            <div id="69b5adc3-359c-4ef2-9357-908fb3d2486e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="224376fd-2dce-428a-851f-71187b512839" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.head().iplot(kind="bubble3d",x='SepalLengthCm', y="SepalWidthCm", z ='PetalLengthCm',size="PetalWidthCm")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8004/531170026.py in <module>
# ----> 1 df.head().iplot(kind="bubble3d",x='SepalLengthCm', y="SepalWidthCm", z ='PetalLengthCm',size="PetalWidthCm")
#
# ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
# ...

# %%
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
try to explore map graph to show and example
